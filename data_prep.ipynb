# %%
# Libraries
import pandas as pd
import numpy as np
from dateutil.relativedelta import relativedelta
import speasy as spz
from speasy import amda
from datetime import datetime, timedelta
import time
import calendar

#Physical  units
e = 1.602176634e-19
m_i = 1.67262192369e-27
m_e = 9.1093837015e-31

def rename(products,data):
    '''
    Rename the columns of dataset based on hard-coded matching between prods name (product.xmlid) and convenient name e.g. 'vx_e' for x velocity of electrons.
    '''
    dic = {'MMS/MMS1/mms1_edp_dce/mms1_edp_dce_gse_brst_l2':['ex','ey','ez'],
                'MMS/MMS2/mms2_edp_dce/mms2_edp_dce_gse_brst_l2':['ex','ey','ez'],
                'MMS/MMS3/mms3_edp_dce/mms3_edp_dce_gse_brst_l2':['ex','ey','ez'],
                'MMS/MMS4/mms4_edp_dce/mms4_edp_dce_gse_brst_l2':['ex','ey','ez'],
                'dce_gse':['ex','ey','ez'],
                'brst_bgse':['bx','by','bz'],
                'brst_jgse':['jx','jy','jz'],
                'brst_dis_n':['i_density'],
                'brst_dis_vgse':['vx_i','vy_i','vz_i'],
                'brst_desm_n':['e_density'],
                'brst_desm_v':['vx_e','vy_e','vz_e'],
                'brst_dispres':['pxx_i', 'pxy_i', 'pxz_i', 'pyx_i', 'pyy_i', 'pyz_i', 'pzx_i', 'pzy_i', 'pzz_i'],
                'brst_desmpres':['pxx_e', 'pxy_e', 'pxz_e', 'pyx_e', 'pyy_e', 'pyz_e', 'pzx_e', 'pzy_e', 'pzz_e'],
                'xyz_gse':['x','y','z'],
    }

    for k, product in enumerate(products):
        data[k].columns = dic[product.spz_uid()[5:]]
        
def re_index(df,index):
    '''
    Just change the index to simplier code later
    '''
    dg = df.copy()
    dg.index = index
    return dg

def downsample(df,index):
    '''
    Downsample the selected dataframe to the selected lenght, and select index as the new indexes for df.
    '''
    dlenght = len(index)
    dg = pd.concat([df.iloc[k*len(df)//dlenght:min(len(df),(k+1)*len(df)//dlenght),:].mean(axis=0) for k in range(dlenght)],axis=1).T
    dg.index = index
    return dg

def upsample(df,index):
    '''
    Downsample the selected dataframe to the selected lenght, and select index as the new indexes for df.
    '''
    dg = pd.DataFrame(index=index,columns=df.columns)
    for col in df.columns:
        dg[col]=np.interp(index, df.index, df[col].values)
    return dg

def keys(t1,t2):
    '''
    Return the correct keys for the dictionnary of timetables according to the months.
    '''
    return['MMS_Burst_Mode_'+dt_keys for dt_keys in pd.date_range(start=t1.strftime('%Y-%m-01') , end=t2.strftime('%Y-%m-'+str(calendar.monthrange(t2.year, t2.month)[1])), freq='ME',inclusive='both').strftime('%Y%B')]

def sat_group(sat=str):
    '''
    Return the corresponding products for a selected satelite
    '''
    if sat[:3] == 'mms':
        MMStree = spz.inventories.tree.amda.Parameters.MMS
        if sat[-1] == '1':
            products = [spz.inventories.data_tree.archive.LASP.MMS.MMS1.mms1_edp_dce.mms1_edp_dce_gse_brst_l2, #burst electric field /!\ Do mms_yaml file cf doc if you need to import this !!!
                #MMStree.MMS1.EDP.fast.mms1_edp_dce.mms1_dce_gse, #electric field
                MMStree.MMS1.FGM.mms1_fgm_brst.mms1_brst_bgse, #magnetic field
                MMStree.MMS1.FPI.burst_mode.mms1_fpi_brst_current.mms1_brst_jgse, #current
                #MMStree.MMS1.FPI.burst_mode.mms1_fpi_brst_dism.mms1_brst_dis_n, #ion density
                MMStree.MMS1.FPI.burst_mode.mms1_fpi_brst_dism.mms1_brst_dis_vgse, #ion velocity
                MMStree.MMS1.FPI.burst_mode.mms1_fpi_brst_desm.mms1_brst_desm_n, #electron density
                MMStree.MMS1.FPI.burst_mode.mms1_fpi_brst_desm.mms1_brst_desm_v, #electron velocity
                #MMStree.MMS1.FPI.burst_mode.mms1_fpi_brst_dism.mms1_brst_dispres, #ion pressure tensor
                #MMStree.MMS1.FPI.burst_mode.mms1_fpi_brst_desm.mms1_brst_desmpres, # electron pressure tensor
                #MMStree.MMS1.Ephemeris.mms1_orb_t89d.mms1_xyz_gse #position xyz
                ]
        if sat[-1] == '2':
            products = [spz.inventories.data_tree.archive.LASP.MMS.MMS2.mms2_edp_dce.mms2_edp_dce_gse_brst_l2, #burst electric field 
                #MMStree.MMS2.EDP.fast.mms2_edp_dce.mms2_dce_gse, #electric field
                MMStree.MMS2.FGM.mms2_fgm_brst.mms2_brst_bgse, #magnetic field
                MMStree.MMS2.FPI.burst_mode.mms2_fpi_brst_current.mms2_brst_jgse, #current
                #MMStree.MMS2.FPI.burst_mode.mms2_fpi_brst_dism.mms2_brst_dis_n, #ion density
                MMStree.MMS2.FPI.burst_mode.mms2_fpi_brst_dism.mms2_brst_dis_vgse, #ion velocity
                MMStree.MMS2.FPI.burst_mode.mms2_fpi_brst_desm.mms2_brst_desm_n, #electron density
                MMStree.MMS2.FPI.burst_mode.mms2_fpi_brst_desm.mms2_brst_desm_v, #electron velocity
                #MMStree.MMS2.FPI.burst_mode.mms2_fpi_brst_dism.mms2_brst_dispres, #ion pressure tensor
                #MMStree.MMS2.FPI.burst_mode.mms2_fpi_brst_desm.mms2_brst_desmpres # electron pressure tensor
                MMStree.MMS2.Ephemeris.mms2_orb_t89d.mms2_xyz_gse, #position xyz
                ]
        if sat[-1] == '3':
            products = [spz.inventories.data_tree.archive.LASP.MMS.MMS3.mms3_edp_dce.mms3_edp_dce_gse_brst_l2, #burst electric field
                #MMStree.MMS3.EDP.fast.mms3_edp_dce.mms3_dce_gse, #electric field
                MMStree.MMS3.FGM.mms3_fgm_brst.mms3_brst_bgse, #magnetic field
                MMStree.MMS3.FPI.burst_mode.mms3_fpi_brst_current.mms3_brst_jgse, #current
                #MMStree.MMS3.FPI.burst_mode.mms3_fpi_brst_dism.mms3_brst_dis_n, #ion density
                MMStree.MMS3.FPI.burst_mode.mms3_fpi_brst_dism.mms3_brst_dis_vgse, #ion velocity
                MMStree.MMS3.FPI.burst_mode.mms3_fpi_brst_desm.mms3_brst_desm_n, #electron density
                MMStree.MMS3.FPI.burst_mode.mms3_fpi_brst_desm.mms3_brst_desm_v, #electron velocity
                #MMStree.MMS3.FPI.burst_mode.mms3_fpi_brst_dism.mms3_brst_dispres, #ion pressure tensor
                #MMStree.MMS3.FPI.burst_mode.mms3_fpi_brst_desm.mms3_brst_desmpres # electron pressure tensor
                MMStree.MMS3.Ephemeris.mms3_orb_t89d.mms3_xyz_gse, #position xyz
                ]
        if sat[-1] == '4':
            products = [spz.inventories.data_tree.archive.LASP.MMS.MMS4.mms4_edp_dce.mms4_edp_dce_gse_brst_l2, #burst electric field
                #MMStree.MMS4.EDP.fast.mms4_edp_dce.mms4_dce_gse, #electric field
                MMStree.MMS4.FGM.mms4_fgm_brst.mms4_brst_bgse, #magnetic field
                MMStree.MMS4.FPI.burst_mode.mms4_fpi_brst_current.mms4_brst_jgse, #current
                #MMStree.MMS4.FPI.burst_mode.mms4_fpi_brst_dism.mms4_brst_dis_n, #ion density
                MMStree.MMS4.FPI.burst_mode.mms4_fpi_brst_dism.mms4_brst_dis_vgse, #ion velocity
                MMStree.MMS4.FPI.burst_mode.mms4_fpi_brst_desm.mms4_brst_desm_n, #electron density
                MMStree.MMS4.FPI.burst_mode.mms4_fpi_brst_desm.mms4_brst_desm_v, #electron velocity
                #MMStree.MMS4.FPI.burst_mode.mms4_fpi_brst_dism.mms4_brst_dispres, #ion pressure tensor
                #MMStree.MMS4.FPI.burst_mode.mms4_fpi_brst_desm.mms4_brst_desmpres # electron pressure tensor
                MMStree.MMS4.Ephemeris.mms4_orb_t89d.mms4_xyz_gse, #position xyz
                ]
    return products

# %%
if __name__ == "__main__":
    import warnings
    from tables import NaturalNameWarning
    warnings.filterwarnings('ignore', category=NaturalNameWarning)

    ## Spacecrafts
    sats = ['mms1','mms2','mms3','mms4']
    ##training
    #times = [(datetime(2016,9,28,16,50,14),datetime(2016,9,28,17,3,31))]
    ## Stawarz & al (2021) - Comparative Analysis of the Various Generalized Ohm's Law Terms in Magnetosheath Turbulence as Observed by Magnetospheric Multiscale
    times = [(datetime(2016,9,28,16,30,0),datetime(2016,9,28,17,30,0)),(datetime(2016,12,9,8,30,0),datetime(2016,12,9,9,30,0)),(datetime(2017,1,28,8,30,0),datetime(2017,1,28,9,30,0))]
    
    ##Data path
    data_path = './data_stawarz_burst.hdf5'
    for sat in sats:
        print(f"Spacecraft = {sat}")
        for t1,t2 in  times:
            print("Data interval:", t1, "to", t2)
            products = sat_group(sat=sat)
            #kept_f = 'brst_desm_n' #Choose the locking frequency, all other data will be upsampled / downsampled to this frequency !!!
            kept_f = f"MMS/MMS{sat[-1]}/{sat}_edp_dce/{sat}_edp_dce_gse_brst_l2" #FOR STAWARZ
            for k, product in enumerate(products):
                if product.spz_uid()[5:]==kept_f:
                    kept_k = k
            print(kept_k)
            burst_timetables = spz.inventories.tree.amda.TimeTables.SharedTimeTables.MMS_BURST_MODE
            bursts = pd.concat([amda.get_timetable(burst_timetables.__dict__[k],disable_cache=True).to_dataframe() for k in keys(t1,t2)])
            bursts = bursts.where((str(t1) < bursts)&(bursts < str(t2))).dropna()
            data_times = pd.DataFrame(np.zeros((len(bursts),4)),columns=['t_import','data_size [GB]','t_downsample','t_saving'])

            for k,event in enumerate(bursts.values):
                try:
                    print("Loading",event[0], "to", event[1], "data with Speasy")
                    start = time.time()
                    data = spz.get_data(products,event[0],event[1],disable_cache=True)
                    end = time.time()
                    data_times.iloc[k,0] = end-start
                    print("Loading OK, time elapsed: ",data_times.iloc[k,0])
                    
                    data = [k.to_dataframe() for k in data]
                    #data = [data[0]['e_gse'].to_dataframe()]+[k.to_dataframe() for k in data[1:]]+[data[0]['dce : qual'].to_dataframe()]
                    
                    rename(products,data)
                    

                    kept_idx = data[kept_k].index
                    print("Resampling everything to the choosen frequency")
                    
                    start = time.time()
                    df = pd.concat([None if len(np.argwhere(np.array([len(dat_) for dat_ in data]) > len(kept_idx))[:,0]) == 0 
                    else pd.concat([downsample(df=data[ind],index=kept_idx) for ind in np.argwhere(np.array([len(dat_) for dat_ in data]) > len(kept_idx))[:,0] ],axis=1),
                                    None if len(np.argwhere(np.array([len(dat_) for dat_ in data]) == len(kept_idx))[:,0]) == 0 
                    else pd.concat([re_index(df=data[ind],index=kept_idx) for ind in np.argwhere(np.array([len(dat_) for dat_ in data]) == len(kept_idx))[:,0] ],axis=1),
                                    None if len(np.argwhere(np.array([len(dat_) for dat_ in data]) < len(kept_idx))[:,0]) == 0 
                    else pd.concat([upsample(df=data[ind],index=kept_idx) for ind in np.argwhere(np.array([len(dat_) for dat_ in data]) < len(kept_idx))[:,0] ],axis=1)],
                                axis=1)
                    
                    #df = df.where(df['dce : qual']>=2).dropna().drop('dce : qual',axis='columns') #select only ok / good data

                    end = time.time()
                    data_times.iloc[k,2] = end-start

                    print("Downsampling OK, time elapsed: ",data_times.iloc[k,2])
                    
                    print("Saving data to HDF5")
                    start = time.time()
                    df.to_hdf(data_path,key=f"{sat}/{datetime.strftime(event[0],format='%Y_%m_%dT%H_%M_%S')}",mode='a', dropna=True)
                    end = time.time()
                    data_times.iloc[k,3] = end-start
                    print("Saving OK, time elapsed: ",data_times.iloc[k,3])

                except Exception as e:
                    print('Data error, burst is skipped')
                    print(e)
                    continue
# Out:
# Spacecraft = mms1
# Data interval: 2016-09-28 16:30:00 to 2016-09-28 17:30:00
# 0
# Loading 2016-09-28 16:34:44+00:00 to 2016-09-28 16:36:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.3827676773071289
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.49839234352111816
# Saving data to HDF5
# Saving OK, time elapsed:  0.17554330825805664
# Loading 2016-09-28 16:48:34+00:00 to 2016-09-28 16:49:14+00:00 data with Speasy
# Loading OK, time elapsed:  0.30881524085998535
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.2423408031463623
# Saving data to HDF5
# Saving OK, time elapsed:  0.09664797782897949
# Loading 2016-09-28 16:49:14+00:00 to 2016-09-28 16:50:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.2494337558746338
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.30441880226135254
# Saving data to HDF5
# Saving OK, time elapsed:  0.11873626708984375
# Loading 2016-09-28 16:50:04+00:00 to 2016-09-28 16:51:14+00:00 data with Speasy
# Loading OK, time elapsed:  0.23039817810058594
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.43298864364624023
# Saving data to HDF5
# Saving OK, time elapsed:  0.1536552906036377
# Loading 2016-09-28 16:51:14+00:00 to 2016-09-28 16:52:24+00:00 data with Speasy
# Loading OK, time elapsed:  0.25166893005371094
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.4490630626678467
# Saving data to HDF5
# Saving OK, time elapsed:  0.15457510948181152
# Loading 2016-09-28 16:52:24+00:00 to 2016-09-28 16:53:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.23363232612609863
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.24429988861083984
# Saving data to HDF5
# Saving OK, time elapsed:  0.09693241119384766
# Loading 2016-09-28 16:53:04+00:00 to 2016-09-28 16:53:44+00:00 data with Speasy
# Loading OK, time elapsed:  0.22756314277648926
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.2525806427001953
# Saving data to HDF5
# Saving OK, time elapsed:  0.09861016273498535
# Loading 2016-09-28 16:53:44+00:00 to 2016-09-28 16:55:44+00:00 data with Speasy
# Loading OK, time elapsed:  0.26879405975341797
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.7626495361328125
# Saving data to HDF5
# Saving OK, time elapsed:  0.2527308464050293
# Loading 2016-09-28 16:55:44+00:00 to 2016-09-28 16:57:34+00:00 data with Speasy
# Loading OK, time elapsed:  0.3097555637359619
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.6940145492553711
# Saving data to HDF5
# Saving OK, time elapsed:  0.22538375854492188
# Loading 2016-09-28 16:57:34+00:00 to 2016-09-28 16:59:34+00:00 data with Speasy
# Loading OK, time elapsed:  0.3056063652038574
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.7477240562438965
# Saving data to HDF5
# Saving OK, time elapsed:  0.24646711349487305
# Loading 2016-09-28 16:59:34+00:00 to 2016-09-28 17:01:24+00:00 data with Speasy
# Loading OK, time elapsed:  0.30623793601989746
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.6923816204071045
# Saving data to HDF5
# Saving OK, time elapsed:  0.2369997501373291
# Loading 2016-09-28 17:01:24+00:00 to 2016-09-28 17:03:34+00:00 data with Speasy
# Loading OK, time elapsed:  0.2864353656768799
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.8123369216918945
# Saving data to HDF5
# Saving OK, time elapsed:  0.3155791759490967
# Loading 2016-09-28 17:08:44+00:00 to 2016-09-28 17:09:24+00:00 data with Speasy
# Loading OK, time elapsed:  0.24968791007995605
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.2476189136505127
# Saving data to HDF5
# Saving OK, time elapsed:  0.1385664939880371
# Loading 2016-09-28 17:10:04+00:00 to 2016-09-28 17:10:54+00:00 data with Speasy
# Loading OK, time elapsed:  0.23413944244384766
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.29917168617248535
# Saving data to HDF5
# Saving OK, time elapsed:  0.12862944602966309
# Loading 2016-09-28 17:21:04+00:00 to 2016-09-28 17:22:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.23182010650634766
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.3775601387023926
# Saving data to HDF5
# Saving OK, time elapsed:  0.2547318935394287
# Loading 2016-09-28 17:25:04+00:00 to 2016-09-28 17:25:54+00:00 data with Speasy
# Loading OK, time elapsed:  0.24422597885131836
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.30190086364746094
# Saving data to HDF5
# Saving OK, time elapsed:  0.12612009048461914
# Loading 2016-09-28 17:28:14+00:00 to 2016-09-28 17:29:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.2321927547454834
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.2963857650756836
# Saving data to HDF5
# Saving OK, time elapsed:  0.15904903411865234
# Data interval: 2016-12-09 08:30:00 to 2016-12-09 09:30:00
# 0
# Loading 2016-12-09 08:58:54+00:00 to 2016-12-09 09:00:54+00:00 data with Speasy
# Loading OK, time elapsed:  0.26761603355407715
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.7606229782104492
# Saving data to HDF5
# Saving OK, time elapsed:  0.27733612060546875
# Loading 2016-12-09 09:00:54+00:00 to 2016-12-09 09:03:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.3024709224700928
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.8269414901733398
# Saving data to HDF5
# Saving OK, time elapsed:  0.28023695945739746
# Loading 2016-12-09 09:03:04+00:00 to 2016-12-09 09:05:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.3049654960632324
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.7550113201141357
# Saving data to HDF5
# Saving OK, time elapsed:  0.25508642196655273
# Loading 2016-12-09 09:05:04+00:00 to 2016-12-09 09:07:14+00:00 data with Speasy
# Loading OK, time elapsed:  0.2854619026184082
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.8327279090881348
# Saving data to HDF5
# Saving OK, time elapsed:  0.31360816955566406
# Loading 2016-12-09 09:22:04+00:00 to 2016-12-09 09:24:14+00:00 data with Speasy
# Loading OK, time elapsed:  0.3021712303161621
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.8828449249267578
# Saving data to HDF5
# Saving OK, time elapsed:  0.2700498104095459
# Loading 2016-12-09 09:24:14+00:00 to 2016-12-09 09:26:24+00:00 data with Speasy
# Loading OK, time elapsed:  0.31546640396118164
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.8232619762420654
# Saving data to HDF5
# Saving OK, time elapsed:  0.2688424587249756
# Loading 2016-12-09 09:26:24+00:00 to 2016-12-09 09:28:34+00:00 data with Speasy
# Loading OK, time elapsed:  0.3028709888458252
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.8192541599273682
# Saving data to HDF5
# Saving OK, time elapsed:  0.2643446922302246
# Data interval: 2017-01-28 08:30:00 to 2017-01-28 09:30:00
# 0
# Loading 2017-01-28 08:30:13+00:00 to 2017-01-28 08:32:43+00:00 data with Speasy
# Loading OK, time elapsed:  0.3307156562805176
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9464428424835205
# Saving data to HDF5
# Saving OK, time elapsed:  0.32197999954223633
# Loading 2017-01-28 08:32:43+00:00 to 2017-01-28 08:35:13+00:00 data with Speasy
# Loading OK, time elapsed:  0.295945405960083
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9360942840576172
# Saving data to HDF5
# Saving OK, time elapsed:  0.30509185791015625
# Loading 2017-01-28 08:35:43+00:00 to 2017-01-28 08:38:23+00:00 data with Speasy
# Loading OK, time elapsed:  0.33677029609680176
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9911861419677734
# Saving data to HDF5
# Saving OK, time elapsed:  0.31473875045776367
# Loading 2017-01-28 08:38:23+00:00 to 2017-01-28 08:40:23+00:00 data with Speasy
# Loading OK, time elapsed:  0.3022916316986084
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.7457065582275391
# Saving data to HDF5
# Saving OK, time elapsed:  0.2832508087158203
# Loading 2017-01-28 08:56:23+00:00 to 2017-01-28 08:58:43+00:00 data with Speasy
# Loading OK, time elapsed:  0.2900886535644531
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.8780820369720459
# Saving data to HDF5
# Saving OK, time elapsed:  0.2923405170440674
# Loading 2017-01-28 09:04:53+00:00 to 2017-01-28 09:07:03+00:00 data with Speasy
# Loading OK, time elapsed:  0.3172569274902344
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.8140137195587158
# Saving data to HDF5
# Saving OK, time elapsed:  0.30011582374572754
# Loading 2017-01-28 09:07:03+00:00 to 2017-01-28 09:09:03+00:00 data with Speasy
# Loading OK, time elapsed:  0.3236565589904785
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.7650918960571289
# Saving data to HDF5
# Saving OK, time elapsed:  0.2634139060974121
# Loading 2017-01-28 09:09:03+00:00 to 2017-01-28 09:11:13+00:00 data with Speasy
# Loading OK, time elapsed:  0.291454553604126
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.8328702449798584
# Saving data to HDF5
# Saving OK, time elapsed:  0.3079869747161865
# Loading 2017-01-28 09:20:33+00:00 to 2017-01-28 09:24:03+00:00 data with Speasy
# Loading OK, time elapsed:  0.3323545455932617
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.3953700065612793
# Saving data to HDF5
# Saving OK, time elapsed:  0.4338855743408203
# Spacecraft = mms2
# Data interval: 2016-09-28 16:30:00 to 2016-09-28 17:30:00
# 0
# Loading 2016-09-28 16:34:44+00:00 to 2016-09-28 16:36:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.30621981620788574
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.6087372303009033
# Saving data to HDF5
# Saving OK, time elapsed:  0.22039222717285156
# Loading 2016-09-28 16:48:34+00:00 to 2016-09-28 16:49:14+00:00 data with Speasy
# Loading OK, time elapsed:  0.29409003257751465
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.29118847846984863
# Saving data to HDF5
# Saving OK, time elapsed:  0.1080172061920166
# Loading 2016-09-28 16:49:14+00:00 to 2016-09-28 16:50:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.280820369720459
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.3696873188018799
# Saving data to HDF5
# Saving OK, time elapsed:  0.13086247444152832
# Loading 2016-09-28 16:50:04+00:00 to 2016-09-28 16:51:14+00:00 data with Speasy
# Loading OK, time elapsed:  0.26869964599609375
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.5154132843017578
# Saving data to HDF5
# Saving OK, time elapsed:  0.17908430099487305
# Loading 2016-09-28 16:51:14+00:00 to 2016-09-28 16:52:24+00:00 data with Speasy
# Loading OK, time elapsed:  0.289597749710083
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.5301787853240967
# Saving data to HDF5
# Saving OK, time elapsed:  0.17980480194091797
# Loading 2016-09-28 16:52:24+00:00 to 2016-09-28 16:53:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.2866802215576172
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.2932772636413574
# Saving data to HDF5
# Saving OK, time elapsed:  0.10383224487304688
# Loading 2016-09-28 16:53:04+00:00 to 2016-09-28 16:53:44+00:00 data with Speasy
# Loading OK, time elapsed:  0.2723276615142822
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.29540133476257324
# Saving data to HDF5
# Saving OK, time elapsed:  0.10637116432189941
# Loading 2016-09-28 16:53:44+00:00 to 2016-09-28 16:55:44+00:00 data with Speasy
# Loading OK, time elapsed:  0.29782867431640625
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9321227073669434
# Saving data to HDF5
# Saving OK, time elapsed:  0.29404377937316895
# Loading 2016-09-28 16:55:44+00:00 to 2016-09-28 16:57:34+00:00 data with Speasy
# Loading OK, time elapsed:  0.35212135314941406
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.8477115631103516
# Saving data to HDF5
# Saving OK, time elapsed:  0.2730114459991455
# Loading 2016-09-28 16:57:34+00:00 to 2016-09-28 16:59:34+00:00 data with Speasy
# Loading OK, time elapsed:  0.34758663177490234
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9181582927703857
# Saving data to HDF5
# Saving OK, time elapsed:  0.29457974433898926
# Loading 2016-09-28 16:59:34+00:00 to 2016-09-28 17:01:24+00:00 data with Speasy
# Loading OK, time elapsed:  0.3483712673187256
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.8419063091278076
# Saving data to HDF5
# Saving OK, time elapsed:  0.27640318870544434
# Loading 2016-09-28 17:01:24+00:00 to 2016-09-28 17:03:34+00:00 data with Speasy
# Loading OK, time elapsed:  0.32024049758911133
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.0033884048461914
# Saving data to HDF5
# Saving OK, time elapsed:  0.42128896713256836
# Loading 2016-09-28 17:08:44+00:00 to 2016-09-28 17:09:24+00:00 data with Speasy
# Loading OK, time elapsed:  0.30518603324890137
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.2968556880950928
# Saving data to HDF5
# Saving OK, time elapsed:  0.11746335029602051
# Loading 2016-09-28 17:10:04+00:00 to 2016-09-28 17:10:54+00:00 data with Speasy
# Loading OK, time elapsed:  0.27921509742736816
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.36278748512268066
# Saving data to HDF5
# Saving OK, time elapsed:  0.13693976402282715
# Loading 2016-09-28 17:21:04+00:00 to 2016-09-28 17:22:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.27542543411254883
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.44761109352111816
# Saving data to HDF5
# Saving OK, time elapsed:  0.1894524097442627
# Loading 2016-09-28 17:25:04+00:00 to 2016-09-28 17:25:54+00:00 data with Speasy
# Loading OK, time elapsed:  0.2823832035064697
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.3529541492462158
# Saving data to HDF5
# Saving OK, time elapsed:  0.12012910842895508
# Loading 2016-09-28 17:28:14+00:00 to 2016-09-28 17:29:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.2760813236236572
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.36832094192504883
# Saving data to HDF5
# Saving OK, time elapsed:  0.13025522232055664
# Data interval: 2016-12-09 08:30:00 to 2016-12-09 09:30:00
# 0
# Loading 2016-12-09 08:58:54+00:00 to 2016-12-09 09:00:54+00:00 data with Speasy
# Loading OK, time elapsed:  0.3000926971435547
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9226579666137695
# Saving data to HDF5
# Saving OK, time elapsed:  0.29561328887939453
# Loading 2016-12-09 09:00:54+00:00 to 2016-12-09 09:03:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.336148738861084
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.0075950622558594
# Saving data to HDF5
# Saving OK, time elapsed:  0.3452579975128174
# Loading 2016-12-09 09:03:04+00:00 to 2016-12-09 09:05:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.34146642684936523
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9318671226501465
# Saving data to HDF5
# Saving OK, time elapsed:  0.29894423484802246
# Loading 2016-12-09 09:05:04+00:00 to 2016-12-09 09:07:14+00:00 data with Speasy
# Loading OK, time elapsed:  0.3146705627441406
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9847183227539062
# Saving data to HDF5
# Saving OK, time elapsed:  0.33495402336120605
# Loading 2016-12-09 09:22:04+00:00 to 2016-12-09 09:24:14+00:00 data with Speasy
# Loading OK, time elapsed:  0.3394191265106201
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9958059787750244
# Saving data to HDF5
# Saving OK, time elapsed:  0.3149087429046631
# Loading 2016-12-09 09:24:14+00:00 to 2016-12-09 09:26:24+00:00 data with Speasy
# Loading OK, time elapsed:  0.335752010345459
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.0122365951538086
# Saving data to HDF5
# Saving OK, time elapsed:  0.38930702209472656
# Loading 2016-12-09 09:26:24+00:00 to 2016-12-09 09:28:34+00:00 data with Speasy
# Loading OK, time elapsed:  0.34688329696655273
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.003600835800171
# Saving data to HDF5
# Saving OK, time elapsed:  0.3171684741973877
# Data interval: 2017-01-28 08:30:00 to 2017-01-28 09:30:00
# 0
# Loading 2017-01-28 08:30:13+00:00 to 2017-01-28 08:32:43+00:00 data with Speasy
# Loading OK, time elapsed:  0.3625006675720215
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.153627634048462
# Saving data to HDF5
# Saving OK, time elapsed:  0.38466334342956543
# Loading 2017-01-28 08:32:43+00:00 to 2017-01-28 08:35:13+00:00 data with Speasy
# Loading OK, time elapsed:  0.3396434783935547
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.142054557800293
# Saving data to HDF5
# Saving OK, time elapsed:  0.371567964553833
# Loading 2017-01-28 08:35:43+00:00 to 2017-01-28 08:38:23+00:00 data with Speasy
# Loading OK, time elapsed:  0.3601040840148926
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.2170524597167969
# Saving data to HDF5
# Saving OK, time elapsed:  0.38517212867736816
# Loading 2017-01-28 08:38:23+00:00 to 2017-01-28 08:40:23+00:00 data with Speasy
# Loading OK, time elapsed:  0.3398406505584717
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9263815879821777
# Saving data to HDF5
# Saving OK, time elapsed:  0.2989497184753418
# Loading 2017-01-28 08:56:23+00:00 to 2017-01-28 08:58:43+00:00 data with Speasy
# Loading OK, time elapsed:  0.331268310546875
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.0924336910247803
# Saving data to HDF5
# Saving OK, time elapsed:  0.3364744186401367
# Loading 2017-01-28 09:04:53+00:00 to 2017-01-28 09:07:03+00:00 data with Speasy
# Loading OK, time elapsed:  0.3466520309448242
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.0028843879699707
# Saving data to HDF5
# Saving OK, time elapsed:  0.34902524948120117
# Loading 2017-01-28 09:07:03+00:00 to 2017-01-28 09:09:03+00:00 data with Speasy
# Loading OK, time elapsed:  0.3492720127105713
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9167776107788086
# Saving data to HDF5
# Saving OK, time elapsed:  0.2877047061920166
# Loading 2017-01-28 09:09:03+00:00 to 2017-01-28 09:11:13+00:00 data with Speasy
# Loading OK, time elapsed:  0.3193802833557129
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9857470989227295
# Saving data to HDF5
# Saving OK, time elapsed:  0.32938432693481445
# Loading 2017-01-28 09:20:33+00:00 to 2017-01-28 09:24:03+00:00 data with Speasy
# Loading OK, time elapsed:  0.3573267459869385
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.6643221378326416
# Saving data to HDF5
# Saving OK, time elapsed:  0.5476038455963135
# Spacecraft = mms3
# Data interval: 2016-09-28 16:30:00 to 2016-09-28 17:30:00
# 0
# Loading 2016-09-28 16:34:44+00:00 to 2016-09-28 16:36:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.30219340324401855
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.6066224575042725
# Saving data to HDF5
# Saving OK, time elapsed:  0.23668837547302246
# Loading 2016-09-28 16:48:34+00:00 to 2016-09-28 16:49:14+00:00 data with Speasy
# Loading OK, time elapsed:  0.2924063205718994
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.2852287292480469
# Saving data to HDF5
# Saving OK, time elapsed:  0.1208333969116211
# Loading 2016-09-28 16:49:14+00:00 to 2016-09-28 16:50:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.27653026580810547
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.37126612663269043
# Saving data to HDF5
# Saving OK, time elapsed:  0.13304734230041504
# Loading 2016-09-28 16:50:04+00:00 to 2016-09-28 16:51:14+00:00 data with Speasy
# Loading OK, time elapsed:  0.2766702175140381
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.5232446193695068
# Saving data to HDF5
# Saving OK, time elapsed:  0.1844801902770996
# Loading 2016-09-28 16:51:14+00:00 to 2016-09-28 16:52:24+00:00 data with Speasy
# Loading OK, time elapsed:  0.2907395362854004
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.5222129821777344
# Saving data to HDF5
# Saving OK, time elapsed:  0.17599916458129883
# Loading 2016-09-28 16:52:24+00:00 to 2016-09-28 16:53:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.2786228656768799
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.2939298152923584
# Saving data to HDF5
# Saving OK, time elapsed:  0.10888147354125977
# Loading 2016-09-28 16:53:04+00:00 to 2016-09-28 16:53:44+00:00 data with Speasy
# Loading OK, time elapsed:  0.27431464195251465
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.2869858741760254
# Saving data to HDF5
# Saving OK, time elapsed:  0.1010737419128418
# Loading 2016-09-28 16:53:44+00:00 to 2016-09-28 16:55:44+00:00 data with Speasy
# Loading OK, time elapsed:  0.2916698455810547
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9121644496917725
# Saving data to HDF5
# Saving OK, time elapsed:  0.28641295433044434
# Loading 2016-09-28 16:55:44+00:00 to 2016-09-28 16:57:34+00:00 data with Speasy
# Loading OK, time elapsed:  0.34507060050964355
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.8386325836181641
# Saving data to HDF5
# Saving OK, time elapsed:  0.27242588996887207
# Loading 2016-09-28 16:57:34+00:00 to 2016-09-28 16:59:34+00:00 data with Speasy
# Loading OK, time elapsed:  0.33576512336730957
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9063870906829834
# Saving data to HDF5
# Saving OK, time elapsed:  0.2908914089202881
# Loading 2016-09-28 16:59:34+00:00 to 2016-09-28 17:01:24+00:00 data with Speasy
# Loading OK, time elapsed:  0.3414878845214844
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.8352260589599609
# Saving data to HDF5
# Saving OK, time elapsed:  0.26559925079345703
# Loading 2016-09-28 17:01:24+00:00 to 2016-09-28 17:03:34+00:00 data with Speasy
# Loading OK, time elapsed:  0.31695127487182617
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9969913959503174
# Saving data to HDF5
# Saving OK, time elapsed:  0.30780696868896484
# Loading 2016-09-28 17:08:44+00:00 to 2016-09-28 17:09:24+00:00 data with Speasy
# Loading OK, time elapsed:  0.29662084579467773
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.28722405433654785
# Saving data to HDF5
# Saving OK, time elapsed:  0.10888910293579102
# Loading 2016-09-28 17:10:04+00:00 to 2016-09-28 17:10:54+00:00 data with Speasy
# Loading OK, time elapsed:  0.26070451736450195
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.35666966438293457
# Saving data to HDF5
# Saving OK, time elapsed:  0.14389705657958984
# Loading 2016-09-28 17:21:04+00:00 to 2016-09-28 17:22:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.27539896965026855
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.4135298728942871
# Saving data to HDF5
# Saving OK, time elapsed:  0.16754961013793945
# Loading 2016-09-28 17:25:04+00:00 to 2016-09-28 17:25:54+00:00 data with Speasy
# Loading OK, time elapsed:  0.2734365463256836
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.34693193435668945
# Saving data to HDF5
# Saving OK, time elapsed:  0.11641788482666016
# Loading 2016-09-28 17:28:14+00:00 to 2016-09-28 17:29:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.26017141342163086
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.3643178939819336
# Saving data to HDF5
# Saving OK, time elapsed:  0.1157534122467041
# Data interval: 2016-12-09 08:30:00 to 2016-12-09 09:30:00
# 0
# Loading 2016-12-09 08:58:54+00:00 to 2016-12-09 09:00:54+00:00 data with Speasy
# Loading OK, time elapsed:  0.28948235511779785
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9009857177734375
# Saving data to HDF5
# Saving OK, time elapsed:  0.2861328125
# Loading 2016-12-09 09:00:54+00:00 to 2016-12-09 09:03:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.33936429023742676
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9937901496887207
# Saving data to HDF5
# Saving OK, time elapsed:  0.3095417022705078
# Loading 2016-12-09 09:03:04+00:00 to 2016-12-09 09:05:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.3347039222717285
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.8988683223724365
# Saving data to HDF5
# Saving OK, time elapsed:  0.28348755836486816
# Loading 2016-12-09 09:05:04+00:00 to 2016-12-09 09:07:14+00:00 data with Speasy
# Loading OK, time elapsed:  0.30783843994140625
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9877529144287109
# Saving data to HDF5
# Saving OK, time elapsed:  0.30948710441589355
# Loading 2016-12-09 09:22:04+00:00 to 2016-12-09 09:24:14+00:00 data with Speasy
# Loading OK, time elapsed:  0.32962822914123535
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9829893112182617
# Saving data to HDF5
# Saving OK, time elapsed:  0.29932737350463867
# Loading 2016-12-09 09:24:14+00:00 to 2016-12-09 09:26:24+00:00 data with Speasy
# Loading OK, time elapsed:  0.33980488777160645
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.991412878036499
# Saving data to HDF5
# Saving OK, time elapsed:  0.3145334720611572
# Loading 2016-12-09 09:26:24+00:00 to 2016-12-09 09:28:34+00:00 data with Speasy
# Loading OK, time elapsed:  0.3332960605621338
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9913544654846191
# Saving data to HDF5
# Saving OK, time elapsed:  0.31246161460876465
# Data interval: 2017-01-28 08:30:00 to 2017-01-28 09:30:00
# 0
# Loading 2017-01-28 08:30:13+00:00 to 2017-01-28 08:32:43+00:00 data with Speasy
# Loading OK, time elapsed:  0.3614645004272461
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.1524138450622559
# Saving data to HDF5
# Saving OK, time elapsed:  0.3344871997833252
# Loading 2017-01-28 08:32:43+00:00 to 2017-01-28 08:35:13+00:00 data with Speasy
# Loading OK, time elapsed:  0.3248469829559326
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.1314544677734375
# Saving data to HDF5
# Saving OK, time elapsed:  0.3529653549194336
# Loading 2017-01-28 08:35:43+00:00 to 2017-01-28 08:38:23+00:00 data with Speasy
# Loading OK, time elapsed:  0.361893892288208
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.2157683372497559
# Saving data to HDF5
# Saving OK, time elapsed:  0.381176233291626
# Loading 2017-01-28 08:38:23+00:00 to 2017-01-28 08:40:23+00:00 data with Speasy
# Loading OK, time elapsed:  0.33976316452026367
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.8987388610839844
# Saving data to HDF5
# Saving OK, time elapsed:  0.3309173583984375
# Loading 2017-01-28 08:56:23+00:00 to 2017-01-28 08:58:43+00:00 data with Speasy
# Loading OK, time elapsed:  0.32373809814453125
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.0635149478912354
# Saving data to HDF5
# Saving OK, time elapsed:  0.3731074333190918
# Loading 2017-01-28 09:04:53+00:00 to 2017-01-28 09:07:03+00:00 data with Speasy
# Loading OK, time elapsed:  0.35408473014831543
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.0136528015136719
# Saving data to HDF5
# Saving OK, time elapsed:  0.318286657333374
# Loading 2017-01-28 09:07:03+00:00 to 2017-01-28 09:09:03+00:00 data with Speasy
# Loading OK, time elapsed:  0.3475360870361328
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.911116361618042
# Saving data to HDF5
# Saving OK, time elapsed:  0.3499338626861572
# Loading 2017-01-28 09:09:03+00:00 to 2017-01-28 09:11:13+00:00 data with Speasy
# Loading OK, time elapsed:  0.32973337173461914
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.0022931098937988
# Saving data to HDF5
# Saving OK, time elapsed:  0.39327120780944824
# Loading 2017-01-28 09:20:33+00:00 to 2017-01-28 09:24:03+00:00 data with Speasy
# Loading OK, time elapsed:  0.36135220527648926
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.6880390644073486
# Saving data to HDF5
# Saving OK, time elapsed:  0.5032804012298584
# Spacecraft = mms4
# Data interval: 2016-09-28 16:30:00 to 2016-09-28 17:30:00
# 0
# Loading 2016-09-28 16:34:44+00:00 to 2016-09-28 16:36:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.3172016143798828
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.6127974987030029
# Saving data to HDF5
# Saving OK, time elapsed:  0.20621943473815918
# Loading 2016-09-28 16:48:34+00:00 to 2016-09-28 16:49:14+00:00 data with Speasy
# Loading OK, time elapsed:  0.3066225051879883
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.2899632453918457
# Saving data to HDF5
# Saving OK, time elapsed:  0.10972929000854492
# Loading 2016-09-28 16:49:14+00:00 to 2016-09-28 16:50:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.28661656379699707
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.37555646896362305
# Saving data to HDF5
# Saving OK, time elapsed:  0.13366007804870605
# Loading 2016-09-28 16:50:04+00:00 to 2016-09-28 16:51:14+00:00 data with Speasy
# Loading OK, time elapsed:  0.2813243865966797
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.5201411247253418
# Saving data to HDF5
# Saving OK, time elapsed:  0.21829795837402344
# Loading 2016-09-28 16:51:14+00:00 to 2016-09-28 16:52:24+00:00 data with Speasy
# Loading OK, time elapsed:  0.28696393966674805
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.5220386981964111
# Saving data to HDF5
# Saving OK, time elapsed:  0.17681312561035156
# Loading 2016-09-28 16:52:24+00:00 to 2016-09-28 16:53:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.29995274543762207
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.29546403884887695
# Saving data to HDF5
# Saving OK, time elapsed:  0.10623025894165039
# Loading 2016-09-28 16:53:04+00:00 to 2016-09-28 16:53:44+00:00 data with Speasy
# Loading OK, time elapsed:  0.2792491912841797
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.29418349266052246
# Saving data to HDF5
# Saving OK, time elapsed:  0.10928511619567871
# Loading 2016-09-28 16:53:44+00:00 to 2016-09-28 16:55:44+00:00 data with Speasy
# Loading OK, time elapsed:  0.28994059562683105
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9288742542266846
# Saving data to HDF5
# Saving OK, time elapsed:  0.2903025150299072
# Loading 2016-09-28 16:55:44+00:00 to 2016-09-28 16:57:34+00:00 data with Speasy
# Loading OK, time elapsed:  0.3453366756439209
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.8402647972106934
# Saving data to HDF5
# Saving OK, time elapsed:  0.27847886085510254
# Loading 2016-09-28 16:57:34+00:00 to 2016-09-28 16:59:34+00:00 data with Speasy
# Loading OK, time elapsed:  0.34569549560546875
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9103379249572754
# Saving data to HDF5
# Saving OK, time elapsed:  0.29509568214416504
# Loading 2016-09-28 16:59:34+00:00 to 2016-09-28 17:01:24+00:00 data with Speasy
# Loading OK, time elapsed:  0.3354763984680176
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.8427505493164062
# Saving data to HDF5
# Saving OK, time elapsed:  0.27518415451049805
# Loading 2016-09-28 17:01:24+00:00 to 2016-09-28 17:03:34+00:00 data with Speasy
# Loading OK, time elapsed:  0.3312339782714844
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.0113985538482666
# Saving data to HDF5
# Saving OK, time elapsed:  0.38283300399780273
# Loading 2016-09-28 17:08:44+00:00 to 2016-09-28 17:09:24+00:00 data with Speasy
# Loading OK, time elapsed:  0.31450581550598145
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.29922986030578613
# Saving data to HDF5
# Saving OK, time elapsed:  0.10846281051635742
# Loading 2016-09-28 17:10:04+00:00 to 2016-09-28 17:10:54+00:00 data with Speasy
# Loading OK, time elapsed:  0.28070664405822754
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.3585495948791504
# Saving data to HDF5
# Saving OK, time elapsed:  0.13274860382080078
# Loading 2016-09-28 17:21:04+00:00 to 2016-09-28 17:22:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.29351043701171875
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.4326159954071045
# Saving data to HDF5
# Saving OK, time elapsed:  0.15051484107971191
# Loading 2016-09-28 17:25:04+00:00 to 2016-09-28 17:25:54+00:00 data with Speasy
# Loading OK, time elapsed:  0.2955968379974365
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.35214781761169434
# Saving data to HDF5
# Saving OK, time elapsed:  0.12296748161315918
# Loading 2016-09-28 17:28:14+00:00 to 2016-09-28 17:29:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.27962684631347656
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.3571434020996094
# Saving data to HDF5
# Saving OK, time elapsed:  0.11961102485656738
# Data interval: 2016-12-09 08:30:00 to 2016-12-09 09:30:00
# 0
# Loading 2016-12-09 08:58:54+00:00 to 2016-12-09 09:00:54+00:00 data with Speasy
# Loading OK, time elapsed:  0.27884364128112793
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9097497463226318
# Saving data to HDF5
# Saving OK, time elapsed:  0.2863004207611084
# Loading 2016-12-09 09:00:54+00:00 to 2016-12-09 09:03:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.3335878849029541
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9957554340362549
# Saving data to HDF5
# Saving OK, time elapsed:  0.3148000240325928
# Loading 2016-12-09 09:03:04+00:00 to 2016-12-09 09:05:04+00:00 data with Speasy
# Loading OK, time elapsed:  0.343153715133667
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9007973670959473
# Saving data to HDF5
# Saving OK, time elapsed:  0.28952836990356445
# Loading 2016-12-09 09:05:04+00:00 to 2016-12-09 09:07:14+00:00 data with Speasy
# Loading OK, time elapsed:  0.3128926753997803
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9865503311157227
# Saving data to HDF5
# Saving OK, time elapsed:  0.35448408126831055
# Loading 2016-12-09 09:22:04+00:00 to 2016-12-09 09:24:14+00:00 data with Speasy
# Loading OK, time elapsed:  0.33454012870788574
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9958987236022949
# Saving data to HDF5
# Saving OK, time elapsed:  0.32201075553894043
# Loading 2016-12-09 09:24:14+00:00 to 2016-12-09 09:26:24+00:00 data with Speasy
# Loading OK, time elapsed:  0.33767056465148926
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.013951301574707
# Saving data to HDF5
# Saving OK, time elapsed:  0.31319093704223633
# Loading 2016-12-09 09:26:24+00:00 to 2016-12-09 09:28:34+00:00 data with Speasy
# Loading OK, time elapsed:  0.33484315872192383
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9990675449371338
# Saving data to HDF5
# Saving OK, time elapsed:  0.3127284049987793
# Data interval: 2017-01-28 08:30:00 to 2017-01-28 09:30:00
# 0
# Loading 2017-01-28 08:30:13+00:00 to 2017-01-28 08:32:43+00:00 data with Speasy
# Loading OK, time elapsed:  0.37852978706359863
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.1292200088500977
# Saving data to HDF5
# Saving OK, time elapsed:  0.40453267097473145
# Loading 2017-01-28 08:32:43+00:00 to 2017-01-28 08:35:13+00:00 data with Speasy
# Loading OK, time elapsed:  0.3537449836730957
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.145413875579834
# Saving data to HDF5
# Saving OK, time elapsed:  0.3515012264251709
# Loading 2017-01-28 08:35:43+00:00 to 2017-01-28 08:38:23+00:00 data with Speasy
# Loading OK, time elapsed:  0.36588525772094727
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.2098009586334229
# Saving data to HDF5
# Saving OK, time elapsed:  0.3666384220123291
# Loading 2017-01-28 08:38:23+00:00 to 2017-01-28 08:40:23+00:00 data with Speasy
# Loading OK, time elapsed:  0.34924912452697754
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9050662517547607
# Saving data to HDF5
# Saving OK, time elapsed:  0.2842843532562256
# Loading 2017-01-28 08:56:23+00:00 to 2017-01-28 08:58:43+00:00 data with Speasy
# Loading OK, time elapsed:  0.3310356140136719
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.0633671283721924
# Saving data to HDF5
# Saving OK, time elapsed:  0.38004207611083984
# Loading 2017-01-28 09:04:53+00:00 to 2017-01-28 09:07:03+00:00 data with Speasy
# Loading OK, time elapsed:  0.35495638847351074
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9876534938812256
# Saving data to HDF5
# Saving OK, time elapsed:  0.301316499710083
# Loading 2017-01-28 09:07:03+00:00 to 2017-01-28 09:09:03+00:00 data with Speasy
# Loading OK, time elapsed:  0.35712289810180664
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9039292335510254
# Saving data to HDF5
# Saving OK, time elapsed:  0.28701353073120117
# Loading 2017-01-28 09:09:03+00:00 to 2017-01-28 09:11:13+00:00 data with Speasy
# Loading OK, time elapsed:  0.3361377716064453
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  0.9796593189239502
# Saving data to HDF5
# Saving OK, time elapsed:  0.3105897903442383
# Loading 2017-01-28 09:20:33+00:00 to 2017-01-28 09:24:03+00:00 data with Speasy
# Loading OK, time elapsed:  0.3629641532897949
# Resampling everything to the choosen frequency
# Downsampling OK, time elapsed:  1.6550042629241943
# Saving data to HDF5
# Saving OK, time elapsed:  0.500831127166748
